# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)

import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
import community

# %%
#G_fb = nx.read_edgelist("facebook_combined.txt", create_using = nx.Graph(), nodetype = int)
g = nx.read_weighted_edgelist("../csv/edges_networkx.csv", delimiter=',', create_using = nx.Graph(), nodetype = int)
print nx.info(g)
# Out:
# Name:
# Type: Graph
# Number of nodes: 2099
# Number of edges: 21887
# Average degree:  20.8547

# %%
nodes=pd.read_csv('../csv/nodes.csv')
old_nodes_df=nodes[nodes.PY<=2006]
new_nodes=nodes[nodes.PY>2006].index.values
g.remove_nodes_from(new_nodes)
print nx.info(g)
# Out:
# Name:
# Type: Graph
# Number of nodes: 941
# Number of edges: 5430
# Average degree:  11.5409

# %%
def cluster(g):
    deg = g.degree()
    to_remove = [n for n in deg if deg[n] == 0]
    g.remove_nodes_from(to_remove)
    print nx.info(g)
    spring_pos = nx.spring_layout(g)
    parts = community.best_partition(g)
    community.modularity(parts,g)
    values = [parts.get(node) for node in g.nodes()]
    print max(values)
    plt.figure(figsize=(20,20))
    plt.axis("off")
    nx.draw_networkx(g, pos = spring_pos, cmap = plt.get_cmap("jet"), node_color = values, node_size = 30, with_labels = False)
    return(parts)
parts=cluster(g)
# Out:
# Name:
# Type: Graph
# Number of nodes: 931
# Number of edges: 5430
# Average degree:  11.6649
# 29

# %%
#old_nodes_df=nodes
old_nodes_df['cluster']=0
for x in parts:
    old_nodes_df.set_value(x,'cluster',parts[x])
df=old_nodes_df
# Out:
# C:\Users\moqri\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
dg=df[['id','cluster']].groupby('cluster').count()
dg=dg.reset_index(drop=True)
dg.rename(columns={'id':'cluster size'},inplace=True)

# %%
df['cluster size']=df.cluster.apply(lambda x: dg.iloc[x])
# Out:
# C:\Users\moqri\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
docs=df.label

# %%
import re
from nltk import stem
porter = stem.porter.PorterStemmer()
from collections import Counter
docs_cleaned = [[re.sub('[.!,;?()\W\d]+', '', word) for word in doc.lower().split()] for doc in docs]

# %%
stop= open ('stopList.txt').read()
stop_list = set(stop.replace("\n", " ").split())
docs_stemed = [[porter.stem(word) for word in document if word not in stop_list] for document in docs_cleaned]

# %%
df['ind']=df.index
df['terms']= docs_stemed
# Out:
# C:\Users\moqri\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\moqri\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
dg['keyword']=''
dg['key terms']=''

for mod in dg.index:
    mod_terms=[]
    for terms in df[df.cluster==mod].terms:
        for term in terms:
            mod_terms.append(term)
            
    words = [word for word in mod_terms if word != '']                
    words_counter = Counter(words)
    top_words=[word for word in words_counter.most_common(5) if word[1]>1]
    dg.set_value(mod,'keyword',top_words)
    
    terms = [words[i]+' '+words[i+1] for i in range(len(words)-1)]
    terms_counter= Counter(terms)
    top_terms=[term for term in terms_counter.most_common(5) if term[1]>1]
    dg.set_value(mod,'key terms',top_terms)

# %%
dg.sort_values('cluster size')
# Out:
#     cluster size  \
# 22  5
# 29  6
# 17  8
# 28  10
# 12  11
# 20  12
# 15  13
# 26  13
# 23  15
# 6   18
# 25  20
# 2   25
# 19  27
# 9   28
# 21  28
# 8   31
# 18  33
# 4   39
# 16  39
# 5   42
# 24  43
# 0   43
# 1   43
# 7   47
# 10  48
# 3   50
# 27  52
# 11  53
# 13  64
# 14  76
#
#                                                                           keyword  \
# 22  [(negoti, 6), (support, 2), (analysi, 2)]
# 29  [(control, 6), (softwar, 2), (process, 2), (portfolio, 2), (develop, 2)]
# 17  [(document, 5), (manag, 2)]
# 28  [(creativ, 9), (idea, 4), (system, 3), (develop, 2), (techniqu, 2)]
# 12  [(privaci, 7), (user, 4), (person, 4), (concern, 3), (model, 3)]
# 20  [(ethic, 6), (piraci, 6), (softwar, 3), (model, 3), (code, 2)]
# 15  [(network, 15), (analysi, 3), (data, 3), (knowledg, 2), (digit, 2)]
# 26  [(commun, 12), (electron, 5), (rich, 3), (model, 3), (work, 2)]
# 23  [(system, 6), (explan, 5), (knowledgebas, 5), (expert, 4), (expertsystem, 3)]
# 6   [(plan, 9), (strateg, 9), (busi, 8), (align, 7), (technolog, 6)]
# 25  [(job, 7), (career, 7), (profession, 6), (turnov, 4), (examin, 4)]
# 2   [(busi, 8), (process, 7), (reengin, 6), (workflow, 6), (distribut, 5)]
# 19  [(system, 8), (error, 6), (disciplin, 5), (approach, 3), (commun, 3)]
# 9   [(suppli, 9), (chain, 8), (edi, 8), (technolog, 6), (electron, 5)]
# 21  [(databas, 12), (system, 5), (secur, 5), (data, 5), (model, 5)]
# 8   [(team, 14), (softwar, 8), (virtual, 8), (develop, 7), (manag, 6)]
# 18  [(system, 15), (methodolog, 9), (develop, 8), (strateg, 6), (sustain, 4)]
# 4   [(web, 13), (onlin, 10), (site, 7), (custom, 6), (search, 5)]
# 16  [(market, 16), (price, 13), (electron, 9), (auction, 6), (technolog, 6)]
# 5   [(measur, 18), (user, 15), (satisfact, 13), (system, 12), (servic, 10)]
# 24  [(technolog, 19), (organ, 6), (chang, 6), (corpor, 5), (organiz, 5)]
# 0   [(trust, 18), (onlin, 10), (implement, 7), (erp, 6), (enterpris, 5)]
# 1   [(comput, 15), (learn, 14), (train, 10), (collabor, 8), (skill, 6)]
# 7   [(technolog, 25), (model, 15), (accept, 14), (standard, 13), (adopt, 13)]
# 10  [(knowledg, 41), (manag, 20), (organiz, 10), (system, 8), (technolog, 6)]
# 3   [(group, 31), (support, 18), (system, 13), (electron, 10), (decis, 9)]
# 27  [(technolog, 16), (manag, 12), (system, 11), (innov, 10), (requir, 8)]
# 11  [(technolog, 18), (project, 18), (risk, 14), (outsourc, 12), (softwar, 10)]
# 13  [(softwar, 18), (system, 15), (model, 15), (decis, 12), (support, 8)]
# 14  [(technolog, 39), (firm, 16), (invest, 16), (product, 15), (perform, 13)]
#
#                                                                                                                         key terms
# 22  [(negoti support, 2)]
# 29  [(softwar develop, 2), (portfolio control, 2)]
# 17  []
# 28  [(creativ support, 2), (support system, 2), (idea gener, 2)]
# 12  [(web person, 2)]
# 20  [(softwar piraci, 3), (piraci price, 2)]
# 15  [(analysi data, 2), (electron network, 2), (empir analysi, 2), (network extern, 2)]
# 26  [(electron commun, 3), (organiz commun, 2), (electron mail, 2)]
# 23  [(expert system, 3), (knowledgebas explan, 2), (knowledgebas system, 2), (induct expert, 2), (theoret foundat, 2)]
# 6   [(busi technolog, 5), (system plan, 3), (informationsystem plan, 3), (strateg align, 3), (align busi, 3)]
# 25  [(system profession, 3), (career orient, 2), (human resourc, 2), (technolog worker, 2), (job skill, 2)]
# 2   [(busi process, 5), (process chang, 2), (workflow manag, 2), (reengin busi, 2), (balanc qualiti, 2)]
# 19  [(refer disciplin, 2), (divers system, 2), (system refer, 2), (ident crisi, 2)]
# 9   [(suppli chain, 8), (electron data, 3), (data interchang, 3), (edi usag, 2)]
# 21  [(databas design, 3), (conceptu model, 2), (data represent, 2), (heterogen databas, 2)]
# 8   [(virtual team, 6), (global virtual, 4), (sourc softwar, 3), (softwar develop, 3), (open sourc, 3)]
# 18  [(system develop, 4), (sustain competit, 2), (strateg informationsystem, 2), (competit advantag, 2), (develop approach, 2)]
# 4   [(web site, 5), (custom retent, 2), (technolog accept, 2), (site usabl, 2), (design web, 2)]
# 16  [(electron market, 3), (competit advantag, 2), (network electron, 2), (market evid, 2), (resourc alloc, 2)]
# 5   [(user satisfact, 7), (servic qualiti, 7), (measur system, 5), (system servic, 5), (user particip, 3)]
# 24  [(technolog organ, 2), (transform work, 2), (technolog implement, 2), (technolog organiz, 2)]
# 0   [(onlin marketplac, 3), (trust onlin, 3), (reput mechan, 2), (role trust, 2), (erp implement, 2)]
# 1   [(comput selfefficaci, 4), (collabor learn, 2), (learn comput, 2), (longitudin field, 2), (train method, 2)]
# 7   [(technolog accept, 9), (belief technolog, 3), (user accept, 3), (technolog usag, 3), (technolog adopt, 3)]
# 10  [(knowledg manag, 14), (manag system, 4), (data qualiti, 3), (organiz knowledg, 3), (knowledg repositori, 2)]
# 3   [(group support, 13), (support system, 12), (electron brainstorm, 7), (decis make, 5), (electron meet, 3)]
# 27  [(technolog innov, 3), (requir elicit, 3), (system technolog, 2), (informationsystem spend, 2), (informationsystem manag, 2)]
# 11  [(softwar project, 7), (real option, 6), (technolog invest, 5), (technolog project, 4), (technolog outsourc, 4)]
# 13  [(decis support, 5), (decis make, 3), (system success, 3), (softwar develop, 3), (manag system, 3)]
# 14  [(technolog invest, 9), (firm perform, 7), (technolog infrastructur, 5), (invest firm, 4), (empir investig, 3)]

# %%
#dendrogram=community.generate_dendrogram(G_fb)[0]
#dendrogram
#com=community.induced_graph(parts,G_fb)
#nx.draw_networkx(com,cmap = plt.get_cmap("jet"), node_size = 10, with_labels = False)

# %%
df.drop('terms',inplace=True, axis=1)
# Out:
# C:\Users\moqri\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df[df.cluster==16].sort('TC',ascending=False)
# Out:
# C:\Users\moqri\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#         id  \
# 796   796
# 1410  1410
# 1031  1031
# 1677  1677
# 1433  1433
# 1123  1123
# 1391  1391
# 1215  1215
# 840   840
# 1284  1284
# 1587  1587
# 1092  1092
# 1355  1355
# 1054  1054
# 807   807
# 915   915
# 1536  1536
# 1118  1118
# 809   809
# 1115  1115
# 866   866
# 897   897
# 1508  1508
# 896   896
# 1680  1680
# 1061  1061
# 947   947
# 1366  1366
# 1373  1373
# 826   826
# 1213  1213
# 1304  1304
# 1700  1700
# 1464  1464
# 1113  1113
# 1561  1561
# 1496  1496
# 1367  1367
# 1305  1305
#
#                                                                                                                                 label  \
# 796   When online reviews meet hyperdifferentiation: A study of the craft beer industry
# 1410  Uses and consequences of electronic markets: An empirical investigation in the aircraft parts industry
# 1031  User heterogeneity and its impact on electronic auction market design: An empirical exploration
# 1677  Electronic Integration and Strategic Advantage: A Quasi-Experimental Study in the Insurance Industry
# 1433  Reengineering the Dutch flower auctions: A framework for analyzing exchange organizations
# 1123  Understanding network effects in software markets: Evidence from Web server pricing
# 1391  Electronic trading and work transformation in the London Insurance Market
# 1215  New buyers' arrival under dynamic pricing market microstructure: The case of group-buying discounts on the Internet
# 840   Internet exchanges for used books: An empirical analysis of product cannibalization and welfare impact
# 1284  Adoption of Internet-based product customization and pricing strategies
# 1587  COMPUTERIZED LOAN ORIGINATION SYSTEMS - AN INDUSTRY CASE-STUDY OF THE ELECTRONIC MARKETS HYPOTHESIS
# 1092  Information goods pricing and copyright enforcement: Welfare analysis
# 1355  Six myths of information and markets: Information technology networks, electronic commerce, and the battle for consumer surplus
# 1054  Replicating online Yankee auctions to analyze auctioneers' and bidders' strategies
# 807   Electronic marketplaces and price transparency: Strategy, information technology, and success
# 915   Toward comprehensive real-time bidder support in iterative combinatorial auctions
# 1536  Added value and pricing with information technology
# 1118  Evolution of prices in electronic markets under diffusion of price-comparison shopping
# 809   Information technology and pricing decisions: Price adjustments in online computer markets
# 1115  A model of neutral B2B
# 866   The impact of e-commerce on competition in the retail brokerage industry
# 897   Effect of electronic secondary markets on the supply chain
# 1508  Alternative securities trading systems: Tests and regulatory implications of the adoption of technology
# 896   Beyond the hype of frictionless markets: Evidence of heterogeneity in price rigidity on the Internet
# 1680  TELCOT - AN APPLICATION OF INFORMATION TECHNOLOGY FOR COMPETITIVE ADVANTAGE IN THE COTTON INDUSTRY
# 1061  Contingency pricing for information goods and services under industrywide performance standard
# 947   Choice of transaction channels: The effects of product characteristics on market evolution
# 1366  Next-generation trading in futures markets: A comparison of open outcry and order matching systems
# 1373  Gaining competitive advantage for trading in emerging capital markets with neural networks
# 826   Market segmentation within consolidated E-markets: A generalized combinatorial auction approach
# 1213  Forward versus spot buying of information goods
# 1304  Extracting consumers' private information for implementing incentive-compatible Internet traffic pricing
# 1700  Alternative Mechanisms of Allocating Computer Resources Under Queueing Delays
# 1464  Information acquisition policies for resource allocation among multiple agents
# 1113  Research report: Intrafirm resource allocation with asymmetric information and negative externalities
# 1561  CONTROLLING INFORMATION-SYSTEM DEPARTMENTS IN THE PRESENCE OF COST INFORMATION ASYMMETRY
# 1496  Pricing computer services under alternative control structures: Tradeoffs and trends
# 1367  Information systems for optimal transaction implementation
# 1305  Trading volumes with and without private information: A study using computerized market experiments
#
#                                                                                                                                                                                                                                 DE  \
# 796   differentiation; online reviews; product positioning; product variety; resonance marketing; word of mouth
# 1410  interorganizational information systems; electronic markets; aircraft parts industry
# 1031  electronic markets; online auctions; bidding strategies; user behavior taxonomy; smart agents; valuation discovery; calibration; simulation
# 1677  Electronic integration; Strategic advantage; Insurance industry; Electronic interfacing; Quasi-experimental study
# 1433  electronic markets; transaction costs; reengineering; technology adoption
# 1123  Hedonic pricing; network effects; network externalities; composite goods; two-sided markets; open standards; mindshare; trialability; World Wide Web server market
# 1391  electronic trading; Giddens' social theory; modernity and self-identity; work transformation; London insurance market; globalization
# 1215  bidding; dynamic pricing; electronic markets; group-buying discounts; Internet-based selling; market microstructure; online retailing; pricing mechanisms
# 840   publisher welfare; retailer welfare; consumer surplus; price competition; used-books sales; electronic markets
# 1284  adoption of information technology; customization; electronic commerce; flexible manufacturing systems
# 1587  COMPUTERIZED LOAN ORIGINATION SYSTEMS; ELECTRONIC MARKETS; ELECTRONIC HIERARCHIES; INCOMPLETE CONTRACTS; SHELTERNET; MORTGAGES
# 1092  copyright; pricing; enforcement
# 1355  electronic markets; networked markets; myths of markets; economic theory; seller strategies; buyer strategies; electronic commerce
# 1054  dynamic pricing; online auctions; simulation
# 807   electronic marketplaces; electronic market theory; electronic commerce; Internet; price transparency; strategic alignment; electronic components industry
# 915   iterative combinatorial auctions; real-time bidder support; bid evaluation metrics; computational techniques for combinatorial auctions
# 1536  economic impacts; interorganizational systems; pricing
# 1118  diffusion,of innovations; Internet economics; price-comparison engines; price-comparison shopping; price competition
# 809   market transparency; strategic pricing; price adjustment; information technology; electronic markets; computer simulations
# 1115  business-to-business e-commerce; intermediation; network effect; pricing strategy
# 866   e-commerce; impact of information technology; unbundling; execution quality
# 897   electronic markets; information goods; market segmentation; quality degradation; supply chain; used goods markets
# 1508  electronic markets; trading systems; experimental economics; technology adoption; financial market simulation
# 896   bookselling; e-commerce; economic analysis; empirical research; empirical regularities; Internet retailing; price rigidity; strategic pricing
# 1680  COMPUTER-BASED TRADING SYSTEMS; ELECTRONIC COMMODITY EXCHANGE; STRATEGIC ADVANTAGE; SMALL BUSINESS; MANAGEMENT OF INFORMATION SYSTEMS; APPLICATION OF INFORMATION TECHNOLOGY
# 1061  contingency pricing; information goods; information technology outsourcing; money-back guarantees; pricing of IT services; quality uncertainty
# 947   electronic commerce; electronic markets; evolutionarily stable equilibrium; evolutionary game theory; market evolution; product characteristics; stochastically stable equilibrium; transaction channel; trusted third party
# 1366  electronic futures trading; screen-based trading; trading automation
# 1373  emerging markets; trading; neural networks; Pacific Rim
# 826   combinatorial auction; electronic markets; market segmentation
# 1213  forward buying; information goods; spot buying; subscription
# 1304  NaN
# 1700  Control of computer resources; Queueing delays; Allocation methods
# 1464  information acquisition policies; discrete resource allocation; team problem solving
# 1113  resource; allocation; asymmetric information; negative externalities
# 1561  MANAGEMENT OF INFORMATION SYSTEMS; INFORMATION ASYMMETRY; MECHANISM DESIGN; CAPACITY; COST CENTER; PROFIT CENTER
# 1496  pricing; computer services; marginal cost
# 1367  electronic trading; fuzzy sets; preference-based trading; securities markets
# 1305  NaN
#
#         PY                                         SO   TC  cluster  \
# 796   2006  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  180  16
# 1410  1998  MIS QUARTERLY                              122  16
# 1031  2004  MIS QUARTERLY                              120  16
# 1677  1990  INFORMATION SYSTEMS RESEARCH               86   16
# 1433  1998  INFORMATION SYSTEMS RESEARCH               73   16
# 1123  2002  MIS QUARTERLY                              73   16
# 1391  1999  INFORMATION SYSTEMS RESEARCH               71   16
# 1215  2001  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  67   16
# 840   2006  INFORMATION SYSTEMS RESEARCH               60   16
# 1284  2000  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  60   16
# 1587  1994  MIS QUARTERLY                              58   16
# 1092  2003  INFORMATION SYSTEMS RESEARCH               58   16
# 1355  1999  MIS QUARTERLY                              56   16
# 1054  2003  INFORMATION SYSTEMS RESEARCH               55   16
# 807   2006  MIS QUARTERLY                              47   16
# 915   2005  INFORMATION SYSTEMS RESEARCH               30   16
# 1536  1995  MIS QUARTERLY                              28   16
# 1118  2002  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  25   16
# 809   2006  MIS QUARTERLY                              25   16
# 1115  2002  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  24   16
# 866   2005  INFORMATION SYSTEMS RESEARCH               23   16
# 897   2005  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  21   16
# 1508  1996  INFORMATION SYSTEMS RESEARCH               19   16
# 896   2005  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  19   16
# 1680  1990  MIS QUARTERLY                              18   16
# 1061  2003  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  13   16
# 947   2005  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  10   16
# 1366  1999  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  10   16
# 1373  1999  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  9    16
# 826   2006  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  9    16
# 1213  2001  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  9    16
# 1304  2000  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  8    16
# 1700  1990  INFORMATION SYSTEMS RESEARCH               8    16
# 1464  1997  INFORMATION SYSTEMS RESEARCH               7    16
# 1113  2002  INFORMATION SYSTEMS RESEARCH               6    16
# 1561  1995  INFORMATION SYSTEMS RESEARCH               6    16
# 1496  1996  INFORMATION SYSTEMS RESEARCH               6    16
# 1367  1999  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  5    16
# 1305  2000  JOURNAL OF MANAGEMENT INFORMATION SYSTEMS  4    16
#
#       cluster size   ind
# 796   39            796
# 1410  39            1410
# 1031  39            1031
# 1677  39            1677
# 1433  39            1433
# 1123  39            1123
# 1391  39            1391
# 1215  39            1215
# 840   39            840
# 1284  39            1284
# 1587  39            1587
# 1092  39            1092
# 1355  39            1355
# 1054  39            1054
# 807   39            807
# 915   39            915
# 1536  39            1536
# 1118  39            1118
# 809   39            809
# 1115  39            1115
# 866   39            866
# 897   39            897
# 1508  39            1508
# 896   39            896
# 1680  39            1680
# 1061  39            1061
# 947   39            947
# 1366  39            1366
# 1373  39            1373
# 826   39            826
# 1213  39            1213
# 1304  39            1304
# 1700  39            1700
# 1464  39            1464
# 1113  39            1113
# 1561  39            1561
# 1496  39            1496
# 1367  39            1367
# 1305  39            1305

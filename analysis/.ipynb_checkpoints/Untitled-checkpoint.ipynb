# %%
import pandas as pd
import glob

# %%
in_path =r'../../data/raw/' # use your path
out_path= "../../data/clean/"
allFiles = glob.glob(in_path + "/*.txt")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_table(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_)
frame.to_csv(out_path+"concat.csv")

# %%
frame.to_csv(out_path+"concat.csv")

# %%
frame
# Out:
#                                                   ﻿PT  AU  BA  BE  \
# J                      Vance, A; Lowry, PB; Eggett, D NaN NaN NaN
# J                           Willison, R; Warkentin, M NaN NaN NaN
# J                    Venkatesh, V; Brown, SA; Bala, H NaN NaN NaN
# J     Adomavicius, G; Curley, SP; Gupta, A; Sanyal, P NaN NaN NaN
# J                Tan, CW; Benbasat, I; Cenfetelli, RT NaN NaN NaN
# J                         Liu, D; Li, X; Santhanam, R NaN NaN NaN
# J         Chen, R; Sharman, R; Rao, HR; Upadhyaya, SJ NaN NaN NaN
# J                      Wang, ETG; Tai, JCF; Grover, V NaN NaN NaN
# J                                               Su, N NaN NaN NaN
# J               Barrett, M; Heracleous, L; Walsham, G NaN NaN NaN
# J                           Polites, GL; Karahanna, E NaN NaN NaN
# J                                            Zhang, P NaN NaN NaN
# J                                Hong, WY; Thong, JYL NaN NaN NaN
# ...

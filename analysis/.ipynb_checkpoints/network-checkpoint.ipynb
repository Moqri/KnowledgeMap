# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
G_fb = nx.read_edgelist("C:/Users/moqri/Desktop/facebook_combined.txt", create_using = nx.Graph(), nodetype = int)

# %%
print nx.info(G_fb)
# Out:
# Name:
# Type: Graph
# Number of nodes: 4039
# Number of edges: 88234
# Average degree:  43.6910

# %%
spring_pos = nx.spring_layout(G_fb)

# %%
plt.axis("off")
nx.draw_networkx(G_fb, pos = spring_pos, with_labels = False, node_size = 35)

# %%
import community
parts = community.best_partition(G_fb)
values = [parts.get(node) for node in G_fb.nodes()]
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-19-22ee0171270e> in <module>()
#       1 import community
# ----> 2 parts = community.best_partition(G_fb)
#       3 values = [parts.get(node) for node in G_fb.nodes()]
#
# AttributeError: 'module' object has no attribute 'best_partition'

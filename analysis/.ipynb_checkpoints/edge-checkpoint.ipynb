# %%
import pandas as pd

# %%
path='../csv/'
lsi=pd.read_csv(path+'p_lsi.csv')
lsi['source_target']=lsi.source.astype(str)+'_'+lsi.target.astype(str)
lsi.shape
# Out:
# (24434, 5)

# %%
bib_all=pd.read_csv(path+'bib.csv')
bib_all['source_target']=bib_all.source.astype(str)+'_'+bib_all.target.astype(str)
bib_all.set_index('source_target', inplace=True,drop=True)
bib_all_l=bib_all.weight

# %%
bib_all_l.index
# Out:
# Index([u'0_1', u'0_4', u'0_11', u'0_12', u'0_15', u'0_29', u'0_35', u'0_40',
#        u'0_48', u'0_78',
#        ...
#        u'2091_2096', u'2091_2098', u'2092_2096', u'2093_2094', u'2094_2095',
#        u'2094_2096', u'2094_2097', u'2094_2099', u'2096_2098', u'2097_2100'],
#       dtype='object', name=u'source_target', length=324888)

# %%
bib_all_l=bib_all.weight
lsi=lsi[(lsi.weight>.2) | (lsi.source_target.isin(bib_all_l.index))]
lsi.shape
# Out:
# (21887, 5)

# %%
bib=pd.read_csv(path+'p_bib.csv')
bib['source_target']=bib.source.astype(str)+'_'+bib.target.astype(str)
bib.set_index('source_target', inplace=True,drop=True)
bib_l=bib.weight
lsi['weight_lsi_bib']=lsi.apply(lambda row: 
                                max(row['weight'],bib_l[row['source_target']]) if row['source_target'] in bib_l 
                                else row['weight'],axis=1)
lsi[lsi.weight_lsi_bib>lsi.weight].shape
# Out:
# (983, 6)

# %%
coc=pd.read_csv(path+'p_coc.csv')
coc['source_target']=coc.source.astype(str)+'_'+coc.target.astype(str)
coc.set_index('source_target', inplace=True,drop=True)
coc_l=coc.weight
lsi['weight_lsi_bib_coc']=lsi.apply(lambda row: 
                                    max(row['weight_lsi_bib'],coc_l[row['source_target']]) if row['source_target'] in coc_l 
                                    else row['weight_lsi_bib'],axis=1)
lsi[lsi.weight_lsi_bib_coc>lsi.weight].shape
# Out:
# (1552, 7)

# %%
lsi.rename(columns={'weight':'old_weight'},inplace=True)
lsi.rename(columns={'weight_lsi_bib_coc':'weight'},inplace=True)

# %%
lsi.to_csv(path+'edges.csv')
lsi[['source','target','weight']].to_csv(path+'edges_networkx.csv',index=False,header=False)
lsi.shape
# Out:
# (21887, 7)

# %%
lsi
# Out:
#        source  target  old_weight        type source_target  weight_lsi_bib  \
# 0           0       1    0.739205  undirected           0_1        0.739205
# 1           0      28    0.291778  undirected          0_28        0.291778
# 2           0      29    0.658454  undirected          0_29        0.658454
# 3           0      90    0.105308  undirected          0_90        0.105308
# 4           0     239    0.469529  undirected         0_239        0.469529
# 5           0     371    0.583882  undirected         0_371        0.583882
# 6           0     398    0.838211  undirected         0_398        0.838211
# 7           0     399    0.314042  undirected         0_399        0.314042
# 8           0     400    0.622969  undirected         0_400        0.622969
# 9           0     401    0.344984  undirected         0_401        0.344984
# 11          0     404    0.394753  undirected         0_404        0.394753
# 12          0     478    0.326730  undirected         0_478        0.326730
# 13          0     545    0.725699  undirected         0_545        0.725699
# 14          0     547    0.269021  undirected         0_547        0.269021
# 15          0     647    0.348463  undirected         0_647        0.348463
# 18          0    1644    0.212172  undirected        0_1644        0.212172
# 19          0    1688    0.547947  undirected        0_1688        0.547947
# 20          0    1706    0.528384  undirected        0_1706        0.528384
# 21          0    1709    0.347317  undirected        0_1709        0.347317
# 22          0    1747    0.747350  undirected        0_1747        0.997738
# 23          0    1756    0.486842  undirected        0_1756        0.486842
# 24          0    1766    0.452421  undirected        0_1766        0.452421
# 25          0    1767    0.255310  undirected        0_1767        0.255310
# 26          0    1793    0.560553  undirected        0_1793        0.560553
# 27          0    1831    0.226538  undirected        0_1831        0.226538
# 28          0    1874    0.801498  undirected        0_1874        0.801498
# 29          0    1916    0.110916  undirected        0_1916        0.110916
# 30          0    1988    0.075799  undirected        0_1988        0.075799
# 31          0    2024    0.680841  undirected        0_2024        0.680841
# 32          0    2082    0.152949  undirected        0_2082        0.152949
# ...       ...     ...         ...         ...           ...             ...
# 24402    2059    2065    0.772316  undirected     2059_2065        0.772316
# 24403    2059    2066    0.979045  undirected     2059_2066        0.979045
# 24404    2059    2067    0.957557  undirected     2059_2067        0.957557
# 24406    2060    2061    0.457373  undirected     2060_2061        0.457373
# 24407    2060    2062    0.282651  undirected     2060_2062        0.282651
# 24408    2060    2063    0.449556  undirected     2060_2063        0.449556
# 24409    2060    2066    0.196169  undirected     2060_2066        0.196169
# 24410    2060    2067    0.485737  undirected     2060_2067        0.485737
# 24411    2061    2062    0.906029  undirected     2061_2062        0.906029
# 24412    2061    2063    0.426718  undirected     2061_2063        0.426718
# 24413    2061    2065    0.707690  undirected     2061_2065        0.707690
# 24414    2061    2066    0.891704  undirected     2061_2066        0.891704
# 24415    2061    2067    0.970041  undirected     2061_2067        0.970041
# 24417    2062    2063    0.583350  undirected     2062_2063        0.583350
# 24418    2062    2065    0.574060  undirected     2062_2065        0.574060
# 24419    2062    2066    0.802439  undirected     2062_2066        0.802439
# 24420    2062    2067    0.931486  undirected     2062_2067        0.931486
# 24421    2063    2066    0.589121  undirected     2063_2066        0.589121
# 24422    2063    2067    0.825359  undirected     2063_2067        0.825359
# 24423    2065    2066    0.612573  undirected     2065_2066        0.612573
# 24424    2065    2067    0.697131  undirected     2065_2067        0.697131
# 24425    2066    2067    0.924938  undirected     2066_2067        0.924938
# 24426    2067    2080    0.335489  undirected     2067_2080        0.335489
# 24427    2068    2095    0.082675  undirected     2068_2095        0.082675
# 24428    2071    2078    0.985675  undirected     2071_2078        0.985675
# 24429    2071    2083    0.326403  undirected     2071_2083        0.878698
# 24430    2078    2083    0.302992  undirected     2078_2083        0.302992
# 24431    2085    2087    0.890762  undirected     2085_2087        0.890762
# 24432    2085    2089    0.442025  undirected     2085_2089        0.442025
# 24433    2087    2089    0.793476  undirected     2087_2089        0.793476
#
#          weight
# 0      0.828776
# 1      0.291778
# 2      0.658454
# 3      0.105308
# 4      0.532453
# 5      0.583882
# 6      0.838211
# 7      0.314042
# 8      0.622969
# 9      0.344984
# 11     0.394753
# 12     0.326730
# 13     0.725699
# 14     0.269021
# 15     0.348463
# 18     0.212172
# 19     0.547947
# 20     0.528384
# 21     0.347317
# 22     0.997738
# 23     0.624244
# 24     0.474176
# 25     0.532453
# 26     0.560553
# 27     0.226538
# 28     0.801498
# 29     0.110916
# 30     0.075799
# 31     0.680841
# 32     0.152949
# ...         ...
# 24402  0.973143
# 24403  0.979045
# 24404  0.957557
# 24406  0.457373
# 24407  0.368632
# 24408  0.449556
# 24409  0.196169
# 24410  0.976385
# 24411  0.906029
# 24412  0.426718
# 24413  0.707690
# 24414  0.891704
# 24415  0.970041
# 24417  0.583350
# 24418  0.574060
# 24419  0.802439
# 24420  0.931486
# 24421  0.589121
# 24422  0.825359
# 24423  0.612573
# 24424  0.697131
# 24425  0.924938
# 24426  0.335489
# 24427  0.082675
# 24428  0.985675
# 24429  0.878698
# 24430  0.302992
# 24431  0.890762
# 24432  0.442025
# 24433  0.793476
#
# [21887 rows x 7 columns]

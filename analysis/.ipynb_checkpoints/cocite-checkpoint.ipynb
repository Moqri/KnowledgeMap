# %%
in_file =r'../../data/clean/articles.csv' 

import pandas as pd
pd.set_option('display.max_columns', 500)

import numpy as np
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import cosine

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(in_file,index_col=False)
df.CR.fillna('',inplace=True)
df_ref=df.CR
refs_dict={}
i=0
for ref in df_ref:
    refs_dict[i]=[ref for ref in ref.split('; ')]
    i=i+1

# %%
refs_basket_dict={}
sources=[
    'MIS QUART',
    'J MANAGE INFORM SYST',
    'INFORM SYST RES'
]
sources=[', '+source+',' for source in sources]

for i in refs_dict:
    refs=refs_dict[i]
    refs_basket=[]
    for ref in refs:
        if any (source in ref for source in sources):
            refs_basket.append(ref)
    refs_basket_dict[i]=refs_basket

# %%
df['author']=df.AU.apply(lambda x: x.split(';')[0].replace(',',''))
df['signiture']=df.author+', '+df.PY.astype(str)+', '+df.J9+', V'+df.VL.astype(str)+', P'+df.BP.astype(str)
df['signiture']=df.apply(lambda x : x.signiture if pd.isnull(x.DI) else x.signiture+', DOI '+x.DI, axis=1 )

# %%
cite = open('..\csv\cite_basket.csv', 'w')
cite.write('citing,cited\n')

for row in refs_basket_dict:
    for ref in refs_basket_dict[row]:
        if ref in df.signiture.values:
            cite.write(str(row)+','+str(np.where(df.signiture==ref)[0][0])+'\n')
cite.close()

# %%
df=pd.read_csv('..\csv\cite_basket.csv',dtype=int)

# %%
max=np.max([df.citing.max(),df.cited.max()])
mm=np.zeros((max+1,max+1))
for row in df.iterrows():
    mm[row[1][0],row[1][1]]=1
#coc=np.tril(np.dot(mm.transpose(),mm),-1)

# %%
coc=np.zeros((max+1,max+1))
for row in range(max+1):
    for col in range(row+1, max+1):
        a=mm[:][row].sum()
        b=mm[:][col].sum()
        ab=np.dot(mm[:][row].transpose(),mm[:][col])
        if ab>2:
            coc[row][col]=ab/(min(a,b)*np.mean([a,b]))

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.imshow(coc, cmap=plt.cm.hot)
plt.colorbar()
plt.show()

# %%
cocite = open('cocite.csv', 'w')
cocite.write('source,target,weight,type\n')

for row in range(coc.shape[0]):
    for col in range(row,coc.shape[1]):
        if coc[row][col] > 0:
            cocite.write(str(row)+','+str(col)+','+str(coc[row][col])+',undirected\n')
cocite.close()

# %%
coc_df=pd.read_csv('cocite.csv')
l=coc_df.weight
hist=plt.hist(l,100)

# %%
l=l.sort_values()
l=l.reset_index(drop=True)
l.plot(drawstyle='steps')

# %%
cum_dist = np.linspace(0.,1.,len(l))
cdf = pd.Series(cum_dist, index=l)
cdf.plot()

# %%
dic=cdf.to_dict()
coc_df['p']=coc_df.weight.apply(lambda x :1- dic[x])
p=coc_df.p
binwidth=.01
hist=plt.hist(p,20)

# %%
p=coc_df.p
p=p.sort_values()
p=p.reset_index(drop=True)
p.plot(drawstyle='steps')

# %%
coc_df.shape
# Out:
# (705, 5)

# %%
coc_df['old_weight']=coc_df.weight
coc_df.drop('weight',inplace=True,axis=1)
coc_df['weight']=1-coc_df.p
coc_df['weight']=coc_df.weight**(1/coc_df.weight)
coc_df[['source','target','weight','type']].to_csv('..\csv\p_coc.csv',index=False)
coc_df.sort('weight', ascending=False)
# Out:
# C:\Users\moqri\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#      source  target        type         p  old_weight         weight
# 642    1012    1206  undirected  0.000000    0.333333   1.000000e+00
# 702    1152    1194  undirected  0.000000    0.333333   1.000000e+00
# 233     188     282  undirected  0.002841    0.285714   9.971510e-01
# 76       37     235  undirected  0.004261    0.250000   9.957204e-01
# 567     905    1010  undirected  0.005682    0.222222   9.942858e-01
# 323     308     344  undirected  0.005682    0.222222   9.942858e-01
# 236     188    1174  undirected  0.008523    0.200000   9.914043e-01
# 279     235     385  undirected  0.008523    0.200000   9.914043e-01
# 232     188     189  undirected  0.008523    0.200000   9.914043e-01
# 349     464     982  undirected  0.008523    0.200000   9.914043e-01
# 148     112     958  undirected  0.008523    0.200000   9.914043e-01
# 480     838    1071  undirected  0.015625    0.187500   9.841290e-01
# 681    1069    1176  undirected  0.015625    0.187500   9.841290e-01
# 326     309    1157  undirected  0.015625    0.187500   9.841290e-01
# 276     231     247  undirected  0.015625    0.187500   9.841290e-01
# 605     937    1206  undirected  0.021307    0.181818   9.782344e-01
# 292     259     839  undirected  0.021307    0.181818   9.782344e-01
# 604     937    1012  undirected  0.021307    0.181818   9.782344e-01
# 261     207     825  undirected  0.021307    0.181818   9.782344e-01
# 237     189     281  undirected  0.021307    0.181818   9.782344e-01
# 219     183     188  undirected  0.021307    0.181818   9.782344e-01
# 324     308     913  undirected  0.029830    0.166667   9.692675e-01
# 259     207     227  undirected  0.029830    0.166667   9.692675e-01
# 465     819    1080  undirected  0.029830    0.166667   9.692675e-01
# 134      90     400  undirected  0.029830    0.166667   9.692675e-01
# 64       29     404  undirected  0.029830    0.166667   9.692675e-01
# 206     157     276  undirected  0.029830    0.166667   9.692675e-01
# 12        1      29  undirected  0.029830    0.166667   9.692675e-01
# 203     153     157  undirected  0.029830    0.166667   9.692675e-01
# 260     207     284  undirected  0.029830    0.166667   9.692675e-01
# ..      ...     ...         ...       ...         ...            ...
# 606     938    1061  undirected  0.958807    0.012719   2.364237e-34
# 209     163     811  undirected  0.960227    0.012698   6.159920e-36
# 612     940    1062  undirected  0.961648    0.012605   1.184853e-37
# 190     147     940  undirected  0.961648    0.012605   1.184853e-37
# 515     859     963  undirected  0.964489    0.012500   1.507803e-41
# 410     803    1061  undirected  0.964489    0.012500   1.507803e-41
# 30       14      70  undirected  0.967330    0.012121   3.313050e-46
# 401     794     953  undirected  0.967330    0.012121   3.313050e-46
# 508     857    1116  undirected  0.970170    0.011905   7.317190e-52
# 211     163     857  undirected  0.970170    0.011905   7.317190e-52
# 510     858     896  undirected  0.970170    0.011905   7.317190e-52
# 186     147     857  undirected  0.970170    0.011905   7.317190e-52
# 502     857     930  undirected  0.970170    0.011905   7.317190e-52
# 420     811     859  undirected  0.977273    0.011594   4.876208e-73
# 464     818     938  undirected  0.978693    0.011364   3.562922e-79
# 500     857     859  undirected  0.980114    0.010811   2.764660e-86
# 582     919    1031  undirected  0.981534    0.010714   1.310102e-94
# 611     940    1056  undirected  0.982955    0.010417  1.796265e-104
# 505     857    1056  undirected  0.984375    0.009868  2.537942e-116
# 511     858     897  undirected  0.984375    0.009868  2.537942e-116
# 609     940     963  undirected  0.987216    0.009539  7.934294e-149
# 400     794     910  undirected  0.988636    0.009259  7.682894e-172
# 36       14     811  undirected  0.990057    0.009070  4.057578e-202
# 568     910     925  undirected  0.991477    0.008547  1.541303e-243
# 427     811    1169  undirected  0.992898    0.008421  2.997410e-303
# 421     811     910  undirected  0.998580    0.006803   0.000000e+00
# 578     919     940  undirected  1.000000    0.006522   0.000000e+00
# 503     857     938  undirected  0.997159    0.007143   0.000000e+00
# 589     925     940  undirected  0.995739    0.007317   0.000000e+00
# 592     925    1169  undirected  0.994318    0.007895   0.000000e+00
#
# [705 rows x 6 columns]
